# %%
import pandas as pd

# %%
# 2 main datatypes
series = pd.Series(["BMW", "Toyota","Honda"])

# %%
series
# Out:
# 0       BMW
# 1    Toyota
# 2     Honda
# dtype: object

# %%
color  = pd.Series(["Red", "Blue","White"])
color
# Out:
# 0      Red
# 1     Blue
# 2    White
# dtype: object

# %%
#Data frame are 2 Dimensional

# %%
car_data = pd.DataFrame({"Car make": series, "Colours": color})
car_data
# Out:
#   Car make Colours
# 0      BMW     Red
# 1   Toyota    Blue
# 2    Honda   White

# %%
df2 = pd.read_csv("car_sales.csv")
df2
# Out:
#    Manufacturer  Sales pkr  Engine_size  Horsepower  Wheelbase
# 0        Suzuki      16919          1.8         140      101.2
# 1         Volvo      39384          3.2         225      108.1
# 2         Honda      14114          3.2         225      106.9
# 3         Acura       8588          3.5         210      114.6
# 4          Audi      20397          1.8         150      102.6
# 5         Tesla       1878          2.8         200      108.7
# 6          Audi        138          4.2         310      113.0
# 7           BMW      19747          2.5         170      107.3
# 8            MG       9231          2.8         193      107.3
# 9           BMW      17527          2.8         193      111.4
# 10        Buick      91561          3.1         175      109.0
# 11          Kia       3935          3.8         240      109.0

# %%
df2.to_csv("Exorted.csv", index = False) #EXPORTS THE dataframe into CSV

# %% [markdown]
# ## Describe Data

# %%
#attribute doesnot have bracket at the end, functions do have such ()
df2.dtypes #shows column with data type
# Out:
# Manufacturer           object
# Sales_in_thousands      int64
# Engine_size           float64
# Horsepower              int64
# Wheelbase             float64
# dtype: object

# %%
df2.columns
# Out:
# Index(['Manufacturer', 'Sales_in_thousands', 'Engine_size', 'Horsepower',
#        'Wheelbase'],
#       dtype='object')

# %%
car = df2.columns
car #stored as lists
# Out:
# Index(['Manufacturer', 'Sales_in_thousands', 'Engine_size', 'Horsepower',
#        'Wheelbase'],
#       dtype='object')

# %%
df2.index #index of the columns
# Out:
# RangeIndex(start=0, stop=12, step=1)

# %%
df2.describe() #statistival values
# Out:
#        Sales_in_thousands  Engine_size  Horsepower   Wheelbase
# count           12.000000    12.000000   12.000000   12.000000
# mean         20284.916667     2.958333  202.583333  108.258333
# std          24814.607518     0.716631   45.420176    3.806802
# min            138.000000     1.800000  140.000000  101.200000
# 25%           7424.750000     2.725000  173.750000  107.200000
# 50%          15516.500000     2.950000  196.500000  108.400000
# 75%          19909.500000     3.275000  225.000000  109.600000
# max          91561.000000     4.200000  310.000000  114.600000

# %%
df2.mean()
# Out:
# C:\Users\19097\AppData\Local\Temp\ipykernel_12688\3587575296.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df2.mean()
# Sales pkr      20284.916667
# Engine_size        2.958333
# Horsepower       202.583333
# Wheelbase        108.258333
# dtype: float64

# %%
avg = pd.Series([30,10,20])
avg.mean()
# Out:
# 20.0

# %%
df2["Engine_size"].sum()
# Out:
# 35.5

# %%
len(df2)
# Out:
# 12

# %%
df2.head(10)
# Out:
#   Manufacturer  Sales pkr  Engine_size  Horsepower  Wheelbase
# 0       Suzuki      16919          1.8         140      101.2
# 1        Volvo      39384          3.2         225      108.1
# 2        Honda      14114          3.2         225      106.9
# 3        Acura       8588          3.5         210      114.6
# 4         Audi      20397          1.8         150      102.6
# 5        Tesla       1878          2.8         200      108.7
# 6         Audi        138          4.2         310      113.0
# 7          BMW      19747          2.5         170      107.3
# 8           MG       9231          2.8         193      107.3
# 9          BMW      17527          2.8         193      111.4

# %%
df2.tail(3)
# Out:
#    Manufacturer  Sales pkr  Engine_size  Horsepower  Wheelbase
# 9           BMW      17527          2.8         193      111.4
# 10        Buick      91561          3.1         175      109.0
# 11          Kia       3935          3.8         240      109.0

# %%
#.loc & .iloc
fds = pd.Series(["Asim", "Asdaq","Kharal","Shahab", "Qasim","Haris"], index = [0,3,3,8,9,10])
fds #gives custom indexes
# Out:
# 0       Asim
# 3      Asdaq
# 3     Kharal
# 8     Shahab
# 9      Qasim
# 10     Haris
# dtype: object

# %%
fds.loc[3] #shows that particular index
# Out:
# 3     Asdaq
# 3    Kharal
# dtype: object

# %%
df2
# Out:
#    Manufacturer  Sales pkr  Engine_size  Horsepower  Wheelbase
# 0        Suzuki      16919          1.8         140      101.2
# 1         Volvo      39384          3.2         225      108.1
# 2         Honda      14114          3.2         225      106.9
# 3         Acura       8588          3.5         210      114.6
# 4          Audi      20397          1.8         150      102.6
# 5         Tesla       1878          2.8         200      108.7
# 6          Audi        138          4.2         310      113.0
# 7           BMW      19747          2.5         170      107.3
# 8            MG       9231          2.8         193      107.3
# 9           BMW      17527          2.8         193      111.4
# 10        Buick      91561          3.1         175      109.0
# 11          Kia       3935          3.8         240      109.0

# %%
df2.loc[2]
# Out:
# Manufacturer    Honda
# Sales pkr       14114
# Engine_size       3.2
# Horsepower        225
# Wheelbase       106.9
# Name: 2, dtype: object

# %%
#.iloc
fds.iloc[3] #shows the position
# Out:
# 'Shahab'

# %%
df2
# Out:
#    Manufacturer  Sales pkr  Engine_size  Horsepower  Wheelbase
# 0        Suzuki      16919          1.8         140      101.2
# 1         Volvo      39384          3.2         225      108.1
# 2         Honda      14114          3.2         225      106.9
# 3         Acura       8588          3.5         210      114.6
# 4          Audi      20397          1.8         150      102.6
# 5         Tesla       1878          2.8         200      108.7
# 6          Audi        138          4.2         310      113.0
# 7           BMW      19747          2.5         170      107.3
# 8            MG       9231          2.8         193      107.3
# 9           BMW      17527          2.8         193      111.4
# 10        Buick      91561          3.1         175      109.0
# 11          Kia       3935          3.8         240      109.0

# %%
df2.iloc[2]
# Out:
# Manufacturer          Honda
# Sales_in_thousands    14114
# Engine_size             3.2
# Horsepower              225
# Wheelbase             106.9
# Name: 2, dtype: object

# %%
df2["Engine_size"]
# Out:
# 0     1.8
# 1     3.2
# 2     3.2
# 3     3.5
# 4     1.8
# 5     2.8
# 6     4.2
# 7     2.5
# 8     2.8
# 9     2.8
# 10    3.1
# 11    3.8
# Name: Engine_size, dtype: float64

# %%
df2.Engine_size
# Out:
# 0     1.8
# 1     3.2
# 2     3.2
# 3     3.5
# 4     1.8
# 5     2.8
# 6     4.2
# 7     2.5
# 8     2.8
# 9     2.8
# 10    3.1
# 11    3.8
# Name: Engine_size, dtype: float64

# %%
df2["Sales pkr"]
# Out:
# 0     16919
# 1     39384
# 2     14114
# 3      8588
# 4     20397
# 5      1878
# 6       138
# 7     19747
# 8      9231
# 9     17527
# 10    91561
# 11     3935
# Name: Sales pkr, dtype: int64

# %%
df2[df2.Engine_size == 3.8]
# Out:
#    Manufacturer  Sales pkr  Engine_size  Horsepower  Wheelbase
# 11          Kia       3935          3.8         240      109.0

# %%
df2[df2.Manufacturer == "Kia" ]
# Out:
#    Manufacturer  Sales pkr  Engine_size  Horsepower  Wheelbase
# 11          Kia       3935          3.8         240      109.0

# %%
df2[df2["Manufacturer"] == "Kia" ]
# Out:
#    Manufacturer  Sales pkr  Engine_size  Horsepower  Wheelbase
# 11          Kia       3935          3.8         240      109.0

# %%
df2
# Out:
#    Manufacturer  Sales pkr  Engine_size  Horsepower  Wheelbase
# 0        Suzuki      16919          1.8         140      101.2
# 1         Volvo      39384          3.2         225      108.1
# 2         Honda      14114          3.2         225      106.9
# 3         Acura       8588          3.5         210      114.6
# 4          Audi      20397          1.8         150      102.6
# 5         Tesla       1878          2.8         200      108.7
# 6          Audi        138          4.2         310      113.0
# 7           BMW      19747          2.5         170      107.3
# 8            MG       9231          2.8         193      107.3
# 9           BMW      17527          2.8         193      111.4
# 10        Buick      91561          3.1         175      109.0
# 11          Kia       3935          3.8         240      109.0

# %%
pd.crosstab(df2["Manufacturer"],df2["Engine_size"])
# Out:
# Engine_size   1.8  2.5  2.8  3.1  3.2  3.5  3.8  4.2
# Manufacturer
# Acura           0    0    0    0    0    1    0    0
# Audi            1    0    0    0    0    0    0    1
# BMW             0    1    1    0    0    0    0    0
# Buick           0    0    0    1    0    0    0    0
# Honda           0    0    0    0    1    0    0    0
# Kia             0    0    0    0    0    0    1    0
# MG              0    0    1    0    0    0    0    0
# Suzuki          1    0    0    0    0    0    0    0
# Tesla           0    0    1    0    0    0    0    0
# Volvo           0    0    0    0    1    0    0    0

# %%
df2
# Out:
#    Manufacturer  Sales pkr  Engine_size  Horsepower  Wheelbase
# 0        Suzuki      16919          1.8         140      101.2
# 1         Volvo      39384          3.2         225      108.1
# 2         Honda      14114          3.2         225      106.9
# 3         Acura       8588          3.5         210      114.6
# 4          Audi      20397          1.8         150      102.6
# 5         Tesla       1878          2.8         200      108.7
# 6          Audi        138          4.2         310      113.0
# 7           BMW      19747          2.5         170      107.3
# 8            MG       9231          2.8         193      107.3
# 9           BMW      17527          2.8         193      111.4
# 10        Buick      91561          3.1         175      109.0
# 11          Kia       3935          3.8         240      109.0

# %%
#grouping

df2.groupby(["Manufacturer"]).mean()
# Out:
#               Sales pkr  Engine_size  Horsepower  Wheelbase
# Manufacturer
# Acura            8588.0         3.50       210.0     114.60
# Audi            10267.5         3.00       230.0     107.80
# BMW             18637.0         2.65       181.5     109.35
# Buick           91561.0         3.10       175.0     109.00
# Honda           14114.0         3.20       225.0     106.90
# Kia              3935.0         3.80       240.0     109.00
# MG               9231.0         2.80       193.0     107.30
# Suzuki          16919.0         1.80       140.0     101.20
# Tesla            1878.0         2.80       200.0     108.70
# Volvo           39384.0         3.20       225.0     108.10

# %%
df2["Engine_size"].plot(kind="bar")
# Out:
# <AxesSubplot: >

# %%
df2["Engine_size"].plot()
# Out:
# <AxesSubplot: >

# %%
df2["Engine_size"].hist()
# Out:
# <AxesSubplot: >

# %%
df2
# Out:
#    Manufacturer  Sales pkr  Engine_size  Horsepower  Wheelbase
# 0        Suzuki      16919          1.8         140      101.2
# 1         Volvo      39384          3.2         225      108.1
# 2         Honda      14114          3.2         225      106.9
# 3         Acura       8588          3.5         210      114.6
# 4          Audi      20397          1.8         150      102.6
# 5         Tesla       1878          2.8         200      108.7
# 6          Audi        138          4.2         310      113.0
# 7           BMW      19747          2.5         170      107.3
# 8            MG       9231          2.8         193      107.3
# 9           BMW      17527          2.8         193      111.4
# 10        Buick      91561          3.1         175      109.0
# 11          Kia       3935          3.8         240      109.0

# %%
df2['Price']=df2['Wheelbase']
df2
# Out:
#    Manufacturer  Sales pkr  Engine_size  Horsepower  Wheelbase  Price
# 0        Suzuki      16919          1.8         140      101.2  101.2
# 1         Volvo      39384          3.2         225      108.1  108.1
# 2         Honda      14114          3.2         225      106.9  106.9
# 3         Acura       8588          3.5         210      114.6  114.6
# 4          Audi      20397          1.8         150      102.6  102.6
# 5         Tesla       1878          2.8         200      108.7  108.7
# 6          Audi        138          4.2         310      113.0  113.0
# 7           BMW      19747          2.5         170      107.3  107.3
# 8            MG       9231          2.8         193      107.3  107.3
# 9           BMW      17527          2.8         193      111.4  111.4
# 10        Buick      91561          3.1         175      109.0  109.0
# 11          Kia       3935          3.8         240      109.0  109.0

# %%
df2['Price'] = df2['Price'].astype(int)
df2
# Out:
#    Manufacturer  Sales pkr  Engine_size  Horsepower  Wheelbase  Price
# 0        Suzuki      16919          1.8         140      101.2    101
# 1         Volvo      39384          3.2         225      108.1    108
# 2         Honda      14114          3.2         225      106.9    106
# 3         Acura       8588          3.5         210      114.6    114
# 4          Audi      20397          1.8         150      102.6    102
# 5         Tesla       1878          2.8         200      108.7    108
# 6          Audi        138          4.2         310      113.0    113
# 7           BMW      19747          2.5         170      107.3    107
# 8            MG       9231          2.8         193      107.3    107
# 9           BMW      17527          2.8         193      111.4    111
# 10        Buick      91561          3.1         175      109.0    109
# 11          Kia       3935          3.8         240      109.0    109

# %%
   df2.Price.plot(kind = "bar")
# Out:
# <AxesSubplot: >

# %% [markdown]
# ## Manipulating Data

# %%
df2["Manufacturer"].str.lower()
# Out:
# 0     suzuki
# 1      volvo
# 2      honda
# 3      acura
# 4       audi
# 5      tesla
# 6       audi
# 7        bmw
# 8         mg
# 9        bmw
# 10     buick
# 11       kia
# Name: Manufacturer, dtype: object

# %%
df3= pd.read_csv("missing.csv")
df3
# Out:
#    Manufacturer  Sales pkr  Engine_size  Horsepower  Wheelbase
# 0        Suzuki    16919.0          1.8       140.0      101.2
# 1         Volvo    39384.0          3.2       225.0      108.1
# 2         Honda    14114.0          3.2         NaN      106.9
# 3         Acura     8588.0          3.5       210.0      114.6
# 4          Audi        NaN          1.8       150.0      102.6
# 5         Tesla     1878.0          2.8       200.0      108.7
# 6          Audi      138.0          4.2       310.0      113.0
# 7           BMW        NaN          2.5         NaN      107.3
# 8            MG     9231.0          2.8       193.0        NaN
# 9           BMW    17527.0          2.8       193.0      111.4
# 10        Buick    91561.0          3.1       175.0      109.0
# 11          Kia     3935.0          3.8       240.0      109.0

# %%
df3['Sales pkr'] = df3['Sales pkr'].fillna(df3['Sales pkr'].mean())
df3
# Out:
#    Manufacturer  Sales pkr  Engine_size  Horsepower  Wheelbase
# 0        Suzuki    16919.0          1.8       140.0      101.2
# 1         Volvo    39384.0          3.2       225.0      108.1
# 2         Honda    14114.0          3.2         NaN      106.9
# 3         Acura     8588.0          3.5       210.0      114.6
# 4          Audi    20327.5          1.8       150.0      102.6
# 5         Tesla     1878.0          2.8       200.0      108.7
# 6          Audi      138.0          4.2       310.0      113.0
# 7           BMW    20327.5          2.5         NaN      107.3
# 8            MG     9231.0          2.8       193.0        NaN
# 9           BMW    17527.0          2.8       193.0      111.4
# 10        Buick    91561.0          3.1       175.0      109.0
# 11          Kia     3935.0          3.8       240.0      109.0

# %%
df3.dropna(inplace =True)
df3
# Out:
#    Manufacturer  Sales pkr  Engine_size  Horsepower  Wheelbase
# 0        Suzuki    16919.0          1.8       140.0      101.2
# 1         Volvo    39384.0          3.2       225.0      108.1
# 3         Acura     8588.0          3.5       210.0      114.6
# 4          Audi    20327.5          1.8       150.0      102.6
# 5         Tesla     1878.0          2.8       200.0      108.7
# 6          Audi      138.0          4.2       310.0      113.0
# 9           BMW    17527.0          2.8       193.0      111.4
# 10        Buick    91561.0          3.1       175.0      109.0
# 11          Kia     3935.0          3.8       240.0      109.0

# %%
df3['wheelcount'] = 4;
df3
# Out:
#    Manufacturer  Sales pkr  Engine_size  Horsepower  Wheelbase  wheelcount
# 0        Suzuki    16919.0          1.8       140.0      101.2           4
# 1         Volvo    39384.0          3.2       225.0      108.1           4
# 3         Acura     8588.0          3.5       210.0      114.6           4
# 4          Audi    20327.5          1.8       150.0      102.6           4
# 5         Tesla     1878.0          2.8       200.0      108.7           4
# 6          Audi      138.0          4.2       310.0      113.0           4
# 9           BMW    17527.0          2.8       193.0      111.4           4
# 10        Buick    91561.0          3.1       175.0      109.0           4
# 11          Kia     3935.0          3.8       240.0      109.0           4

# %%
df3 = df3.drop("wheelcount",axis = 1)

# %%
df3
# Out:
#    Manufacturer  Sales pkr  Engine_size  Horsepower  Wheelbase
# 0        Suzuki    16919.0          1.8       140.0      101.2
# 1         Volvo    39384.0          3.2       225.0      108.1
# 3         Acura     8588.0          3.5       210.0      114.6
# 4          Audi    20327.5          1.8       150.0      102.6
# 5         Tesla     1878.0          2.8       200.0      108.7
# 6          Audi      138.0          4.2       310.0      113.0
# 9           BMW    17527.0          2.8       193.0      111.4
# 10        Buick    91561.0          3.1       175.0      109.0
# 11          Kia     3935.0          3.8       240.0      109.0
